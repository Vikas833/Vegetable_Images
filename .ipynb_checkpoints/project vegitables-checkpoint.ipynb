# %% [markdown]
# <h1>Car Brand Recognization Project</h1>

# %% [markdown]
# <h3>Importing Important Python Libraries</h3>

# %%
import numpy as np
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, Dropout
from tensorflow.keras import datasets, layers, models
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

from PIL import Image, ImageOps 
from IPython.display import display

# %% [markdown]
# <h3>Assigning The directories</h3>

# %%
img_dir1 = 'train'
img_dir2 = "test"
batch_size = 64
img_size = 150
input_shape = (150, 150, 1)

# %% [markdown]
# <h3>Importing The Dataset</h3>

# %%
data_gen = ImageDataGenerator(rescale = 1/255, validation_split=0.2)
data_gen_test = ImageDataGenerator(rescale=1/255)
     
train_data = data_gen.flow_from_directory(img_dir1, target_size=(img_size, img_size),subset="training", color_mode="grayscale", shuffle=True, class_mode="binary")
val_data = data_gen.flow_from_directory(img_dir1, target_size=(img_size, img_size),subset="validation", color_mode="grayscale", shuffle=True, class_mode="binary")
test_data = data_gen_test.flow_from_directory(img_dir2, target_size=(img_size, img_size), color_mode="grayscale", shuffle=False, batch_size=batch_size, class_mode="binary")
# Out:
# Found 2684 images belonging to 7 classes.
# Found 668 images belonging to 7 classes.
# Found 813 images belonging to 7 classes.

# %%
labels = train_data.class_indices
classes = list(labels.keys())
classes
# Out:
# ['Audi',
#  'Hyundai Creta',
#  'Mahindra Scorpio',
#  'Rolls Royce',
#  'Swift',
#  'Tata Safari',
#  'Toyota Innova']

# %% [markdown]
# <h3>Make the Convolutional Nueral Network</h3>

# %%
model = Sequential()
model.add(keras.layers.InputLayer(shape=input_shape))
model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))

# %%
# cnn = models.Sequential([
#     layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
#     layers.MaxPooling2D((2, 2)),
    
#     layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
#     layers.MaxPooling2D((2, 2)),
    
#     layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
#     layers.MaxPooling2D((2, 2)),
    
#     layers.Flatten(),
#     layers.Dense(64, activation='relu'),
#     layers.Dense(10, activation='softmax')
# ])

# %% [markdown]
# <h3>Compiling the Nueral Network</h3>

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36992)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       2,367,552 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,460,874 (9.39 MB)
#  Trainable params: 2,460,874 (9.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# cnn.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# %% [markdown]
# <h3>Compiling the Nueral Network</h3>

# %%
with tf.device("/device:GPU:0"):
    his = model.fit(train_data, epochs=10, validation_data=val_data, verbose=1)
# Out:
# C:\Users\vikas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 42s 457ms/step - accuracy: 0.2262 - loss: 2.0159 - val_accuracy: 0.3802 - val_loss: 1.7543
# Epoch 2/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 37s 434ms/step - accuracy: 0.3717 - loss: 1.7198 - val_accuracy: 0.5180 - val_loss: 1.4219
# Epoch 3/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 37s 438ms/step - accuracy: 0.5377 - loss: 1.3045 - val_accuracy: 0.6213 - val_loss: 1.1974
# Epoch 4/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 36s 430ms/step - accuracy: 0.6676 - loss: 0.9559 - val_accuracy: 0.6602 - val_loss: 1.0737
# Epoch 5/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 36s 432ms/step - accuracy: 0.7927 - loss: 0.6126 - val_accuracy: 0.6482 - val_loss: 1.1032
# Epoch 6/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 40s 469ms/step - accuracy: 0.8494 - loss: 0.4402 - val_accuracy: 0.6931 - val_loss: 1.1294
# Epoch 7/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 40s 474ms/step - accuracy: 0.9069 - loss: 0.2739 - val_accuracy: 0.7051 - val_loss: 1.1706
# Epoch 8/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 36s 431ms/step - accuracy: 0.9421 - loss: 0.1842 - val_accuracy: 0.6886 - val_loss: 1.3242
# Epoch 9/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 37s 436ms/step - accuracy: 0.9552 - loss: 0.1458 - val_accuracy: 0.6976 - val_loss: 1.5264
# Epoch 10/10
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 36s 434ms/step - accuracy: 0.9546 - loss: 0.1420 - val_accuracy: 0.6991 - val_loss: 1.3426

# %% [markdown]
# <h3>Evaluating the Model</h3>

# %%
train_loss, train_acc = model.evaluate(train_data)
test_loss, test_acc = model.evaluate(train_data)
print(f"Train data loss is {train_loss}, Train data Accuracy {train_acc}, Test data loss is {test_loss}, Test data Accuracy is {test_acc}")
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - accuracy: 0.9989 - loss: 0.0238
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - accuracy: 0.9997 - loss: 0.0229
# Train data loss is 0.023730454966425896, Train data Accuracy 0.9988822937011719, Test data loss is 0.023730454966425896, Test data Accuracy is 0.9988822937011719

# %%
data = np.ndarray(shape=(1, 150, 150, 1), dtype=np.float32)
image = Image.open("Cars_Dataset\144.jpg")
size = (150, 150)
image = ImageOps.grayscale(image)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
image_array = np.array(image)
display(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 data = np.ndarray(shape=(1, 150, 150, 1), dtype=np.float32)
# ----> 2 image = Image.open("Cars_Dataset\144.jpg")
#       3 size = (150, 150)
#       4 image = ImageOps.grayscale(image)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\tasks\\deep learning\\Cars_Dataset\\Cars_Datasetd.jpg'

# %% [markdown]
# <h3>Plotting Graph of Training and validation accuracy and loss</h3>

# %%
loss = his.history['loss']
val_loss = his.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = his.history['accuracy']
val_acc = his.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
